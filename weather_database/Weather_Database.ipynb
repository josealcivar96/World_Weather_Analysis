# %%
#import dependencies
import pandas as pd
import numpy as np 
import requests as rq
import time
from citipy import citipy

# %%
#get API key
from config import weather_api_key as w_key

# %%
#build URL for OpenWeatherAPI call
url = "https://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + w_key

# %% [markdown]
# ## Generating Random Coordinates

# %%
#create random latitudes and longitudes
lats = np.random.uniform(-90, 90, size = 2000)
lons = np.random.uniform(-90, 90, size = 2000)
lat_lon_coords = zip(lats, lons)
coordinates = list(lat_lon_coords)

# %% [markdown]
# ## Getting nearest cities

# %%
#list to hold cities
cities = []

#identify nearest city for each lat and lon combo
for coord in coordinates:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    
    #if city is unique, add to the cities list
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 769

# %% [markdown]
# ## Getting Weather Information

# %%
#create list to hold weather data
city_weather_data = []

#start logging
print('Beginning Data Retrieval     ')
print('-----------------------------')

#create counters
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    #group cities in sets of 50 for log purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    #create endpoint url with each city
    city_url = url + '&q=' + city.replace(' ', '+')
    
    #log url, record, set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    #add 1 to record count
    record_count += 1
    
    #API request
    try:
        #parse json and retrieve data
        city_weather = rq.get(city_url).json()
        #get needed data
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lon = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_cloudiness = city_weather['clouds']['all']
        city_wind_speed = city_weather['wind']['speed']
        city_description = city_weather['weather'][0]['description']
        #append info to city_weather_data list
        city_weather_data.append({"City": city.title(),
                                 "Country": city_country,
                                 "Lat": city_lat,
                                 "Lon": city_lon,
                                 "Max Temp": city_max_temp,
                                 "Humidity": city_humidity,
                                 "Cloudiness": city_cloudiness,
                                 "Wind Speed": city_wind_speed,
                                 "Current Description": city_description})
    #if error, skip
    except:
        print("City not found. Skipping...")
        pass
    
    #add timer so there are no more than 60 calls per min
    time.sleep(1)

#indicate Data Loading is Complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | porto belo
# Processing Record 4 of Set 1 | upata
# Processing Record 5 of Set 1 | husavik
# Processing Record 6 of Set 1 | mahibadhoo
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | kongolo
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | havre-saint-pierre
# Processing Record 11 of Set 1 | rawson
# Processing Record 12 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 1 | karasburg
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | bagan
# Processing Record 16 of Set 1 | vila franca do campo
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | bulnes
# Processing Record 23 of Set 1 | virginia beach
# Processing Record 24 of Set 1 | nuuk
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | strezhevoy
# Processing Record 27 of Set 1 | shache
# Processing Record 28 of Set 1 | tessalit
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | caucel
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | tshikapa
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | dingle
# Processing Record 36 of Set 1 | novouzensk
# Processing Record 37 of Set 1 | batticaloa
# Processing Record 38 of Set 1 | wad madani
# Processing Record 39 of Set 1 | klaksvik
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | janakkala
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | ust-tsilma
# Processing Record 44 of Set 1 | hit
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | lasa
# Processing Record 47 of Set 1 | kazanskaya
# Processing Record 48 of Set 1 | novopskov
# Processing Record 49 of Set 1 | bud
# Processing Record 50 of Set 1 | qostanay
# Processing Record 1 of Set 2 | sinnamary
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | olafsvik
# Processing Record 4 of Set 2 | sao joao da barra
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | clyde river
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | abu dhabi
# Processing Record 10 of Set 2 | nandikotkur
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | poptun
# Processing Record 14 of Set 2 | derzhavinsk
# Processing Record 15 of Set 2 | mancio lima
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | tombouctou
# Processing Record 18 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 2 | antalaha
# Processing Record 20 of Set 2 | turukhansk
# Processing Record 21 of Set 2 | floro
# Processing Record 22 of Set 2 | jalu
# Processing Record 23 of Set 2 | chesterton
# Processing Record 24 of Set 2 | beloha
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | tucurui
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | sarkand
# Processing Record 30 of Set 2 | oistins
# Processing Record 31 of Set 2 | pitimbu
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | tornio
# Processing Record 34 of Set 2 | burica
# City not found. Skipping...
# Processing Record 35 of Set 2 | parry sound
# Processing Record 36 of Set 2 | den helder
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 2 | the valley
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | novo aripuana
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | ginir
# Processing Record 44 of Set 2 | renfrew
# Processing Record 45 of Set 2 | mosalsk
# Processing Record 46 of Set 2 | paranagua
# Processing Record 47 of Set 2 | george town
# Processing Record 48 of Set 2 | shelburne
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | rio das pedras
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | salalah
# Processing Record 4 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 3 | asosa
# Processing Record 6 of Set 3 | inongo
# Processing Record 7 of Set 3 | rundu
# Processing Record 8 of Set 3 | stockton-on-tees
# Processing Record 9 of Set 3 | taucha
# Processing Record 10 of Set 3 | fomboni
# Processing Record 11 of Set 3 | dalbandin
# Processing Record 12 of Set 3 | kokstad
# Processing Record 13 of Set 3 | saint-augustin
# Processing Record 14 of Set 3 | nagua
# Processing Record 15 of Set 3 | basoko
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 3 | kedougou
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | touros
# Processing Record 21 of Set 3 | bibbiena
# Processing Record 22 of Set 3 | rondonopolis
# Processing Record 23 of Set 3 | torzhok
# Processing Record 24 of Set 3 | enterprise
# Processing Record 25 of Set 3 | waddan
# Processing Record 26 of Set 3 | aksay
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | hauterive
# Processing Record 29 of Set 3 | jaguaruna
# Processing Record 30 of Set 3 | cumana
# Processing Record 31 of Set 3 | tarko-sale
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | cheremukhovo
# Processing Record 34 of Set 3 | nadym
# Processing Record 35 of Set 3 | khash
# Processing Record 36 of Set 3 | ubinskoye
# Processing Record 37 of Set 3 | luena
# Processing Record 38 of Set 3 | edd
# Processing Record 39 of Set 3 | grand gaube
# Processing Record 40 of Set 3 | la ligua
# Processing Record 41 of Set 3 | teseney
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | zheleznodorozhnyy
# Processing Record 44 of Set 3 | los llanos de aridane
# Processing Record 45 of Set 3 | baracoa
# Processing Record 46 of Set 3 | praia da vitoria
# Processing Record 47 of Set 3 | pueblo bello
# Processing Record 48 of Set 3 | conceicao do araguaia
# Processing Record 49 of Set 3 | cockburn town
# Processing Record 50 of Set 3 | dudinka
# Processing Record 1 of Set 4 | padang
# Processing Record 2 of Set 4 | japura
# Processing Record 3 of Set 4 | jimma
# Processing Record 4 of Set 4 | magugu
# Processing Record 5 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 4 | hun
# Processing Record 7 of Set 4 | general roca
# Processing Record 8 of Set 4 | ipora
# Processing Record 9 of Set 4 | stokmarknes
# Processing Record 10 of Set 4 | saint-pierre
# Processing Record 11 of Set 4 | kalat
# Processing Record 12 of Set 4 | yarada
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | salinopolis
# Processing Record 15 of Set 4 | teodoro sampaio
# Processing Record 16 of Set 4 | lincoln
# Processing Record 17 of Set 4 | jubayl
# City not found. Skipping...
# Processing Record 18 of Set 4 | gidole
# Processing Record 19 of Set 4 | gaborone
# Processing Record 20 of Set 4 | dubai
# Processing Record 21 of Set 4 | sarila
# Processing Record 22 of Set 4 | rize
# Processing Record 23 of Set 4 | kutum
# Processing Record 24 of Set 4 | brae
# Processing Record 25 of Set 4 | opuwo
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | sinop
# Processing Record 28 of Set 4 | plettenberg bay
# Processing Record 29 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 30 of Set 4 | piacabucu
# Processing Record 31 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 4 | jijiga
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | verkhnyaya inta
# Processing Record 35 of Set 4 | codrington
# Processing Record 36 of Set 4 | vestmanna
# Processing Record 37 of Set 4 | butterworth
# Processing Record 38 of Set 4 | narsaq
# Processing Record 39 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 4 | balykshi
# Processing Record 41 of Set 4 | gazojak
# Processing Record 42 of Set 4 | necochea
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | darnah
# Processing Record 45 of Set 4 | kargil
# Processing Record 46 of Set 4 | grand haven
# Processing Record 47 of Set 4 | belem de sao francisco
# Processing Record 48 of Set 4 | maunabo
# Processing Record 49 of Set 4 | namibe
# Processing Record 50 of Set 4 | mbanza-ngungu
# Processing Record 1 of Set 5 | aksarka
# Processing Record 2 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 3 of Set 5 | boddam
# Processing Record 4 of Set 5 | turbat
# Processing Record 5 of Set 5 | maceio
# Processing Record 6 of Set 5 | rio gallegos
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | chaumont
# Processing Record 9 of Set 5 | yacuiba
# Processing Record 10 of Set 5 | souillac
# Processing Record 11 of Set 5 | santa cruz
# Processing Record 12 of Set 5 | camocim
# Processing Record 13 of Set 5 | saquarema
# Processing Record 14 of Set 5 | verkhnyaya toyma
# Processing Record 15 of Set 5 | acari
# Processing Record 16 of Set 5 | galle
# Processing Record 17 of Set 5 | taoudenni
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | gumdag
# Processing Record 20 of Set 5 | mangrol
# Processing Record 21 of Set 5 | kailahun
# Processing Record 22 of Set 5 | varna
# Processing Record 23 of Set 5 | santa maria
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | ustyuzhna
# Processing Record 26 of Set 5 | soyo
# Processing Record 27 of Set 5 | olavarria
# Processing Record 28 of Set 5 | gurupa
# Processing Record 29 of Set 5 | ribnica
# Processing Record 30 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 5 | mapiri
# Processing Record 32 of Set 5 | youghal
# Processing Record 33 of Set 5 | chapais
# Processing Record 34 of Set 5 | bourges
# Processing Record 35 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | nador
# Processing Record 38 of Set 5 | uribia
# Processing Record 39 of Set 5 | betioky
# Processing Record 40 of Set 5 | aripuana
# Processing Record 41 of Set 5 | galliate
# Processing Record 42 of Set 5 | bandarbeyla
# Processing Record 43 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 5 | suluq
# Processing Record 45 of Set 5 | saint-raphael
# Processing Record 46 of Set 5 | pindorama
# Processing Record 47 of Set 5 | hammerfest
# Processing Record 48 of Set 5 | agirish
# Processing Record 49 of Set 5 | grajau
# Processing Record 50 of Set 5 | marsh harbour
# Processing Record 1 of Set 6 | termiz
# Processing Record 2 of Set 6 | madimba
# Processing Record 3 of Set 6 | sharanga
# Processing Record 4 of Set 6 | babynino
# Processing Record 5 of Set 6 | moultrie
# Processing Record 6 of Set 6 | kinna
# Processing Record 7 of Set 6 | havelock
# Processing Record 8 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 6 | sirjan
# Processing Record 10 of Set 6 | yuryuzan
# Processing Record 11 of Set 6 | uaua
# Processing Record 12 of Set 6 | vestmannaeyjar
# Processing Record 13 of Set 6 | la linea
# Processing Record 14 of Set 6 | lillehammer
# Processing Record 15 of Set 6 | moss point
# Processing Record 16 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 6 | ugoofaaru
# Processing Record 18 of Set 6 | kuytun
# Processing Record 19 of Set 6 | marienburg
# Processing Record 20 of Set 6 | east kilbride
# Processing Record 21 of Set 6 | les cayes
# Processing Record 22 of Set 6 | port-cartier
# Processing Record 23 of Set 6 | prainha
# Processing Record 24 of Set 6 | san rafael
# Processing Record 25 of Set 6 | stephenville
# Processing Record 26 of Set 6 | salinas
# Processing Record 27 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | eyl
# Processing Record 31 of Set 6 | awash
# Processing Record 32 of Set 6 | benghazi
# Processing Record 33 of Set 6 | sechura
# Processing Record 34 of Set 6 | montepuez
# Processing Record 35 of Set 6 | la palma
# Processing Record 36 of Set 6 | krasnoarmeysk
# Processing Record 37 of Set 6 | saint-joseph
# Processing Record 38 of Set 6 | grindavik
# Processing Record 39 of Set 6 | lubao
# Processing Record 40 of Set 6 | puerto ayacucho
# Processing Record 41 of Set 6 | carnarvon
# Processing Record 42 of Set 6 | inirida
# Processing Record 43 of Set 6 | gao
# Processing Record 44 of Set 6 | borculo
# Processing Record 45 of Set 6 | nizwa
# Processing Record 46 of Set 6 | doba
# Processing Record 47 of Set 6 | port victoria
# Processing Record 48 of Set 6 | jhang
# Processing Record 49 of Set 6 | berlevag
# Processing Record 50 of Set 6 | stratford-upon-avon
# Processing Record 1 of Set 7 | sabha
# Processing Record 2 of Set 7 | abu samrah
# Processing Record 3 of Set 7 | thompson
# Processing Record 4 of Set 7 | boa vista
# Processing Record 5 of Set 7 | muzhi
# Processing Record 6 of Set 7 | axim
# Processing Record 7 of Set 7 | alunitdag
# City not found. Skipping...
# Processing Record 8 of Set 7 | nouadhibou
# Processing Record 9 of Set 7 | torbay
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | natal
# Processing Record 12 of Set 7 | santa isabel do rio negro
# Processing Record 13 of Set 7 | logrono
# Processing Record 14 of Set 7 | esil
# Processing Record 15 of Set 7 | faya
# Processing Record 16 of Set 7 | hofn
# Processing Record 17 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 7 | bahia blanca
# Processing Record 19 of Set 7 | uyutne
# Processing Record 20 of Set 7 | paragominas
# Processing Record 21 of Set 7 | abhar
# Processing Record 22 of Set 7 | waupun
# Processing Record 23 of Set 7 | matao
# Processing Record 24 of Set 7 | myra
# Processing Record 25 of Set 7 | lephepe
# City not found. Skipping...
# Processing Record 26 of Set 7 | sovetskiy
# Processing Record 27 of Set 7 | azua
# Processing Record 28 of Set 7 | ulyanovo
# City not found. Skipping...
# Processing Record 29 of Set 7 | riviere-au-renard
# Processing Record 30 of Set 7 | agadez
# Processing Record 31 of Set 7 | chardara
# Processing Record 32 of Set 7 | vardo
# Processing Record 33 of Set 7 | mayumba
# Processing Record 34 of Set 7 | port blair
# Processing Record 35 of Set 7 | gbadolite
# Processing Record 36 of Set 7 | cap-aux-meules
# Processing Record 37 of Set 7 | izvoarele sucevei
# Processing Record 38 of Set 7 | estelle
# Processing Record 39 of Set 7 | diego de almagro
# Processing Record 40 of Set 7 | lebu
# Processing Record 41 of Set 7 | raudeberg
# Processing Record 42 of Set 7 | mezen
# Processing Record 43 of Set 7 | ostrovnoy
# Processing Record 44 of Set 7 | moen
# Processing Record 45 of Set 7 | togur
# Processing Record 46 of Set 7 | andenes
# Processing Record 47 of Set 7 | umm lajj
# Processing Record 48 of Set 7 | monte alegre
# Processing Record 49 of Set 7 | bilopillya
# Processing Record 50 of Set 7 | zijpe
# City not found. Skipping...
# Processing Record 1 of Set 8 | san juan
# Processing Record 2 of Set 8 | maun
# Processing Record 3 of Set 8 | saint leonard
# Processing Record 4 of Set 8 | cochrane
# Processing Record 5 of Set 8 | mehran
# Processing Record 6 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 8 | gizeh
# Processing Record 8 of Set 8 | moose factory
# Processing Record 9 of Set 8 | vostochnyy
# Processing Record 10 of Set 8 | studena
# Processing Record 11 of Set 8 | arusha
# Processing Record 12 of Set 8 | nisia floresta
# Processing Record 13 of Set 8 | barcelos
# Processing Record 14 of Set 8 | quelimane
# Processing Record 15 of Set 8 | hualmay
# Processing Record 16 of Set 8 | alekseyevka
# Processing Record 17 of Set 8 | semey
# Processing Record 18 of Set 8 | misratah
# Processing Record 19 of Set 8 | lundamo
# Processing Record 20 of Set 8 | bubaque
# Processing Record 21 of Set 8 | tsiroanomandidy
# Processing Record 22 of Set 8 | bekovo
# Processing Record 23 of Set 8 | hambantota
# Processing Record 24 of Set 8 | firovo
# Processing Record 25 of Set 8 | iberia
# Processing Record 26 of Set 8 | marsa matruh
# Processing Record 27 of Set 8 | olive branch
# Processing Record 28 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 8 | bathsheba
# Processing Record 30 of Set 8 | washington
# Processing Record 31 of Set 8 | sao mateus do sul
# Processing Record 32 of Set 8 | zolotonosha
# Processing Record 33 of Set 8 | aksu
# Processing Record 34 of Set 8 | skibbereen
# Processing Record 35 of Set 8 | resavica
# Processing Record 36 of Set 8 | jibuti
# Processing Record 37 of Set 8 | cayenne
# Processing Record 38 of Set 8 | la rioja
# Processing Record 39 of Set 8 | shiraz
# Processing Record 40 of Set 8 | ceres
# Processing Record 41 of Set 8 | governador valadares
# Processing Record 42 of Set 8 | turinsk
# Processing Record 43 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 44 of Set 8 | springbok
# Processing Record 45 of Set 8 | strabychovo
# Processing Record 46 of Set 8 | antofagasta
# Processing Record 47 of Set 8 | lusambo
# Processing Record 48 of Set 8 | louis trichardt
# Processing Record 49 of Set 8 | sosnytsya
# Processing Record 50 of Set 8 | tamasane
# Processing Record 1 of Set 9 | manavalakurichi
# Processing Record 2 of Set 9 | benguela
# Processing Record 3 of Set 9 | apollona
# City not found. Skipping...
# Processing Record 4 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 5 of Set 9 | sorkjosen
# Processing Record 6 of Set 9 | sheltozero
# Processing Record 7 of Set 9 | sept-iles
# Processing Record 8 of Set 9 | olinda
# Processing Record 9 of Set 9 | gonen
# Processing Record 10 of Set 9 | ushtobe
# Processing Record 11 of Set 9 | aranos
# Processing Record 12 of Set 9 | snina
# Processing Record 13 of Set 9 | kviteseid
# Processing Record 14 of Set 9 | immokalee
# Processing Record 15 of Set 9 | rognan
# Processing Record 16 of Set 9 | gzhatsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | laishevo
# Processing Record 18 of Set 9 | urla
# Processing Record 19 of Set 9 | emba
# Processing Record 20 of Set 9 | fethiye
# Processing Record 21 of Set 9 | bilma
# Processing Record 22 of Set 9 | salta
# Processing Record 23 of Set 9 | chimbote
# Processing Record 24 of Set 9 | artvin
# Processing Record 25 of Set 9 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 26 of Set 9 | rochegda
# Processing Record 27 of Set 9 | henties bay
# Processing Record 28 of Set 9 | parabel
# Processing Record 29 of Set 9 | eirunepe
# Processing Record 30 of Set 9 | artyom
# Processing Record 31 of Set 9 | lalmanir hat
# City not found. Skipping...
# Processing Record 32 of Set 9 | richards bay
# Processing Record 33 of Set 9 | pinega
# Processing Record 34 of Set 9 | kushmurun
# Processing Record 35 of Set 9 | boende
# Processing Record 36 of Set 9 | mitsamiouli
# Processing Record 37 of Set 9 | ippy
# Processing Record 38 of Set 9 | hvolsvollur
# Processing Record 39 of Set 9 | thinadhoo
# Processing Record 40 of Set 9 | indiana
# Processing Record 41 of Set 9 | la tuque
# Processing Record 42 of Set 9 | saint anthony
# Processing Record 43 of Set 9 | mequon
# Processing Record 44 of Set 9 | alexandria
# Processing Record 45 of Set 9 | vieux-habitants
# Processing Record 46 of Set 9 | sidi qasim
# City not found. Skipping...
# Processing Record 47 of Set 9 | bagua grande
# Processing Record 48 of Set 9 | san pedro
# Processing Record 49 of Set 9 | nivala
# Processing Record 50 of Set 9 | praia
# Processing Record 1 of Set 10 | saint-leu
# Processing Record 2 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 10 | sorland
# Processing Record 4 of Set 10 | yar-sale
# Processing Record 5 of Set 10 | issia
# Processing Record 6 of Set 10 | camacha
# Processing Record 7 of Set 10 | atar
# Processing Record 8 of Set 10 | luba
# Processing Record 9 of Set 10 | pangnirtung
# Processing Record 10 of Set 10 | nicolas bravo
# Processing Record 11 of Set 10 | san andres
# Processing Record 12 of Set 10 | manhuacu
# Processing Record 13 of Set 10 | sur
# Processing Record 14 of Set 10 | caucaia
# Processing Record 15 of Set 10 | pasni
# Processing Record 16 of Set 10 | wageningen
# Processing Record 17 of Set 10 | sassandra
# Processing Record 18 of Set 10 | lodwar
# Processing Record 19 of Set 10 | loukhi
# Processing Record 20 of Set 10 | borama
# City not found. Skipping...
# Processing Record 21 of Set 10 | tanda
# Processing Record 22 of Set 10 | shrewsbury
# Processing Record 23 of Set 10 | sikar
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | bawku
# Processing Record 26 of Set 10 | birjand
# Processing Record 27 of Set 10 | las palmas
# Processing Record 28 of Set 10 | atmakur
# Processing Record 29 of Set 10 | aquidauana
# Processing Record 30 of Set 10 | longonjo
# Processing Record 31 of Set 10 | aswan
# Processing Record 32 of Set 10 | lugovoy
# Processing Record 33 of Set 10 | pasinler
# Processing Record 34 of Set 10 | puerto lopez
# Processing Record 35 of Set 10 | maniitsoq
# Processing Record 36 of Set 10 | bijar
# Processing Record 37 of Set 10 | coruripe
# Processing Record 38 of Set 10 | calais
# Processing Record 39 of Set 10 | tanout
# Processing Record 40 of Set 10 | abnub
# Processing Record 41 of Set 10 | akdepe
# Processing Record 42 of Set 10 | naryan-mar
# Processing Record 43 of Set 10 | pelym
# Processing Record 44 of Set 10 | ancona
# Processing Record 45 of Set 10 | paamiut
# Processing Record 46 of Set 10 | jacareacanga
# Processing Record 47 of Set 10 | marawi
# Processing Record 48 of Set 10 | kudahuvadhoo
# Processing Record 49 of Set 10 | pregradnaya
# Processing Record 50 of Set 10 | itacare
# Processing Record 1 of Set 11 | gambela
# Processing Record 2 of Set 11 | monster
# Processing Record 3 of Set 11 | rafaela
# Processing Record 4 of Set 11 | bonavista
# Processing Record 5 of Set 11 | camana
# Processing Record 6 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 11 | monrovia
# Processing Record 8 of Set 11 | kaniama
# Processing Record 9 of Set 11 | cabedelo
# Processing Record 10 of Set 11 | ratnagiri
# Processing Record 11 of Set 11 | coihaique
# Processing Record 12 of Set 11 | lock haven
# Processing Record 13 of Set 11 | rocha
# Processing Record 14 of Set 11 | keetmanshoop
# Processing Record 15 of Set 11 | pithora
# Processing Record 16 of Set 11 | vagur
# Processing Record 17 of Set 11 | adrar
# Processing Record 18 of Set 11 | saint combs
# City not found. Skipping...
# Processing Record 19 of Set 11 | waslala
# Processing Record 20 of Set 11 | masyaf
# Processing Record 21 of Set 11 | huaraz
# Processing Record 22 of Set 11 | le port
# Processing Record 23 of Set 11 | surt
# Processing Record 24 of Set 11 | snezhnogorsk
# Processing Record 25 of Set 11 | santa cruz de la palma
# Processing Record 26 of Set 11 | malanje
# Processing Record 27 of Set 11 | kindu
# Processing Record 28 of Set 11 | san lawrenz
# Processing Record 29 of Set 11 | nantucket
# Processing Record 30 of Set 11 | loandjili
# Processing Record 31 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 11 | amapa
# Processing Record 33 of Set 11 | iquique
# Processing Record 34 of Set 11 | sao jose do belmonte
# Processing Record 35 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 36 of Set 11 | edelira
# Processing Record 37 of Set 11 | igbo ora
# Processing Record 38 of Set 11 | seredka
# Processing Record 39 of Set 11 | rypefjord
# Processing Record 40 of Set 11 | belokurikha
# Processing Record 41 of Set 11 | pokhara
# Processing Record 42 of Set 11 | chabahar
# Processing Record 43 of Set 11 | imeni babushkina
# Processing Record 44 of Set 11 | mitoc
# Processing Record 45 of Set 11 | chute-aux-outardes
# Processing Record 46 of Set 11 | muhos
# Processing Record 47 of Set 11 | oussouye
# Processing Record 48 of Set 11 | kalmunai
# Processing Record 49 of Set 11 | zabid
# Processing Record 50 of Set 11 | sakskobing
# Processing Record 1 of Set 12 | varberg
# Processing Record 2 of Set 12 | carauari
# Processing Record 3 of Set 12 | gwanda
# Processing Record 4 of Set 12 | gualaquiza
# Processing Record 5 of Set 12 | synya
# Processing Record 6 of Set 12 | comodoro rivadavia
# Processing Record 7 of Set 12 | koping
# Processing Record 8 of Set 12 | gogrial
# Processing Record 9 of Set 12 | makat
# Processing Record 10 of Set 12 | necocli
# Processing Record 11 of Set 12 | trairi
# Processing Record 12 of Set 12 | kautokeino
# Processing Record 13 of Set 12 | kosonsoy
# Processing Record 14 of Set 12 | marquette
# Processing Record 15 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 12 | luanda
# Processing Record 17 of Set 12 | najran
# Processing Record 18 of Set 12 | alcacer do sal
# Processing Record 19 of Set 12 | aviles
# Processing Record 20 of Set 12 | belfast
# Processing Record 21 of Set 12 | port-gentil
# Processing Record 22 of Set 12 | arona
# Processing Record 23 of Set 12 | svetlyy
# Processing Record 24 of Set 12 | rio grande
# Processing Record 25 of Set 12 | blagoyevo
# Processing Record 26 of Set 12 | ust-ishim
# Processing Record 27 of Set 12 | rorvik
# Processing Record 28 of Set 12 | kupino
# Processing Record 29 of Set 12 | dasoguz
# Processing Record 30 of Set 12 | atasu
# Processing Record 31 of Set 12 | zhob
# Processing Record 32 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 12 | bella vista
# Processing Record 34 of Set 12 | birao
# Processing Record 35 of Set 12 | huarmey
# Processing Record 36 of Set 12 | mocuba
# Processing Record 37 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 12 | glace bay
# Processing Record 39 of Set 12 | talnakh
# Processing Record 40 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 12 | omboue
# Processing Record 42 of Set 12 | bereda
# Processing Record 43 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 12 | joshimath
# Processing Record 45 of Set 12 | mehamn
# Processing Record 46 of Set 12 | moundou
# Processing Record 47 of Set 12 | teguldet
# Processing Record 48 of Set 12 | skjervoy
# Processing Record 49 of Set 12 | chervona sloboda
# Processing Record 50 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 1 of Set 13 | fort dix
# Processing Record 2 of Set 13 | mao
# Processing Record 3 of Set 13 | calabozo
# Processing Record 4 of Set 13 | bouca
# Processing Record 5 of Set 13 | palmas de monte alto
# Processing Record 6 of Set 13 | riyadh
# Processing Record 7 of Set 13 | tiznit
# Processing Record 8 of Set 13 | kapoeta
# Processing Record 9 of Set 13 | lascahobas
# Processing Record 10 of Set 13 | kremenchuk
# Processing Record 11 of Set 13 | manaure
# Processing Record 12 of Set 13 | ankola
# Processing Record 13 of Set 13 | kavaratti
# Processing Record 14 of Set 13 | maarianhamina
# Processing Record 15 of Set 13 | tete
# Processing Record 16 of Set 13 | coelho neto
# Processing Record 17 of Set 13 | villa carlos paz
# Processing Record 18 of Set 13 | sfantu gheorghe
# Processing Record 19 of Set 13 | kamakwie
# Processing Record 20 of Set 13 | oranjestad
# Processing Record 21 of Set 13 | mardin
# Processing Record 22 of Set 13 | diamantina
# Processing Record 23 of Set 13 | dondo
# Processing Record 24 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 25 of Set 13 | jaisalmer
# Processing Record 26 of Set 13 | middletown
# Processing Record 27 of Set 13 | athol
# Processing Record 28 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 13 | kumluca
# Processing Record 30 of Set 13 | porto-vecchio
# Processing Record 31 of Set 13 | lambarene
# Processing Record 32 of Set 13 | havoysund
# Processing Record 33 of Set 13 | boqueirao
# Processing Record 34 of Set 13 | gobabis
# Processing Record 35 of Set 13 | kemijarvi
# Processing Record 36 of Set 13 | roald
# Processing Record 37 of Set 13 | yegorlykskaya
# Processing Record 38 of Set 13 | barranca
# Processing Record 39 of Set 13 | sinnar
# Processing Record 40 of Set 13 | vizinga
# Processing Record 41 of Set 13 | hurghada
# Processing Record 42 of Set 13 | san jose
# Processing Record 43 of Set 13 | suhl
# Processing Record 44 of Set 13 | el tigre
# Processing Record 45 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 46 of Set 13 | matara
# Processing Record 47 of Set 13 | qandala
# Processing Record 48 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 13 | filingue
# Processing Record 50 of Set 13 | arlit
# Processing Record 1 of Set 14 | koszeg
# Processing Record 2 of Set 14 | adre
# Processing Record 3 of Set 14 | nyamuswa
# Processing Record 4 of Set 14 | dutlwe
# Processing Record 5 of Set 14 | westport
# Processing Record 6 of Set 14 | flic en flac
# Processing Record 7 of Set 14 | pirapora
# Processing Record 8 of Set 14 | umea
# Processing Record 9 of Set 14 | monte cristi
# City not found. Skipping...
# Processing Record 10 of Set 14 | hazaribag
# Processing Record 11 of Set 14 | urengoy
# Processing Record 12 of Set 14 | matadi
# Processing Record 13 of Set 14 | soledade
# Processing Record 14 of Set 14 | maine-soroa
# Processing Record 15 of Set 14 | ancud
# Processing Record 16 of Set 14 | saint-georges
# Processing Record 17 of Set 14 | walvis bay
# Processing Record 18 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 14 | atyashevo
# Processing Record 20 of Set 14 | lerwick
# Processing Record 21 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 14 | tingi
# Processing Record 23 of Set 14 | charyshskoye
# Processing Record 24 of Set 14 | quatre cocos
# Processing Record 25 of Set 14 | mahanoro
# Processing Record 26 of Set 14 | conde
# Processing Record 27 of Set 14 | svetlogorsk
# Processing Record 28 of Set 14 | sambava
# Processing Record 29 of Set 14 | road town
# Processing Record 30 of Set 14 | nieuw amsterdam
# Processing Record 31 of Set 14 | rincon
# Processing Record 32 of Set 14 | caraballeda
# Processing Record 33 of Set 14 | fort-shevchenko
# Processing Record 34 of Set 14 | vilcun
# Processing Record 35 of Set 14 | doha
# Processing Record 36 of Set 14 | beyneu
# Processing Record 37 of Set 14 | weligama
# Processing Record 38 of Set 14 | dukhovshchina
# Processing Record 39 of Set 14 | abha
# Processing Record 40 of Set 14 | bardiyah
# Processing Record 41 of Set 14 | la esperanza
# Processing Record 42 of Set 14 | itarema
# Processing Record 43 of Set 14 | turtas
# Processing Record 44 of Set 14 | megion
# Processing Record 45 of Set 14 | kamenka
# Processing Record 46 of Set 14 | tikapur
# Processing Record 47 of Set 14 | araouane
# Processing Record 48 of Set 14 | santiago del estero
# Processing Record 49 of Set 14 | kaduqli
# Processing Record 50 of Set 14 | jizan
# Processing Record 1 of Set 15 | rania
# Processing Record 2 of Set 15 | cheremisinovo
# Processing Record 3 of Set 15 | hornbaek
# Processing Record 4 of Set 15 | malanville
# Processing Record 5 of Set 15 | tukrah
# Processing Record 6 of Set 15 | tarrafal
# Processing Record 7 of Set 15 | mantua
# Processing Record 8 of Set 15 | bahar
# Processing Record 9 of Set 15 | leh
# Processing Record 10 of Set 15 | black river
# Processing Record 11 of Set 15 | vikulovo
# Processing Record 12 of Set 15 | valledupar
# Processing Record 13 of Set 15 | betanzos
# Processing Record 14 of Set 15 | kisesa
# Processing Record 15 of Set 15 | mattru
# Processing Record 16 of Set 15 | toul
# Processing Record 17 of Set 15 | altoona
# Processing Record 18 of Set 15 | sarakhs
# Processing Record 19 of Set 15 | amlame
# Processing Record 20 of Set 15 | uvira
# Processing Record 21 of Set 15 | nyrob
# Processing Record 22 of Set 15 | buchanan
# Processing Record 23 of Set 15 | sisimiut
# Processing Record 24 of Set 15 | orotina
# Processing Record 25 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 27 of Set 15 | lichinga
# Processing Record 28 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 29 of Set 15 | monduli
# Processing Record 30 of Set 15 | tornabe
# Processing Record 31 of Set 15 | cap malheureux
# Processing Record 32 of Set 15 | ouro preto do oeste
# Processing Record 33 of Set 15 | dodola
# Processing Record 34 of Set 15 | rabat
# Processing Record 35 of Set 15 | campoverde
# Processing Record 36 of Set 15 | yialos
# City not found. Skipping...
# Processing Record 37 of Set 15 | lamu
# Processing Record 38 of Set 15 | bara
# Processing Record 39 of Set 15 | a
# City not found. Skipping...
# Processing Record 40 of Set 15 | sao domingos
# Processing Record 41 of Set 15 | kinkala
# Processing Record 42 of Set 15 | lenger
# Processing Record 43 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 44 of Set 15 | san luis
# Processing Record 45 of Set 15 | ailigandi
# Processing Record 46 of Set 15 | vallenar
# Processing Record 47 of Set 15 | labytnangi
# Processing Record 48 of Set 15 | lixourion
# Processing Record 49 of Set 15 | bodo
# Processing Record 50 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 16 | grafenau
# Processing Record 2 of Set 16 | maragogi
# Processing Record 3 of Set 16 | alta floresta
# Processing Record 4 of Set 16 | makokou
# Processing Record 5 of Set 16 | inhambane
# Processing Record 6 of Set 16 | kismayo
# Processing Record 7 of Set 16 | caldas novas
# Processing Record 8 of Set 16 | namanyere
# Processing Record 9 of Set 16 | rosetta
# Processing Record 10 of Set 16 | sao felix do xingu
# Processing Record 11 of Set 16 | jaleswar
# Processing Record 12 of Set 16 | maicao
# Processing Record 13 of Set 16 | campo verde
# Processing Record 14 of Set 16 | berezovka
# Processing Record 15 of Set 16 | san-pedro
# Processing Record 16 of Set 16 | mahasamund
# Processing Record 17 of Set 16 | gamba
# Processing Record 18 of Set 16 | chernukha
# Processing Record 19 of Set 16 | gbarnga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ## Saving CSV

# %%
#adding to df
city_weather_df = pd.DataFrame(city_weather_data)
city_weather_df.head(10)
# Out:
#                  City Country      Lat      Lon  Max Temp  Humidity  \
# 0              Dikson      RU  73.5069  80.5464      0.90        84
# 1       Mar Del Plata      AR -38.0023 -57.5575      8.40        57
# 2          Porto Belo      BR -27.1578 -48.5531     20.91        87
# 3               Upata      VE   8.0086 -62.3989     26.22        70
# 4             Husavik      IS  66.0449 -17.3389     11.95        69
# 5          Mahibadhoo      MV   3.7833  72.9667     27.21        75
# 6            Saldanha      ZA -33.0117  17.9442     13.03        84
# 7             Kongolo      CD  -5.3833  27.0000     22.83        39
# 8          Bredasdorp      ZA -34.5322  20.0403     13.62        54
# 9  Havre-Saint-Pierre      CA  50.2334 -63.5986     17.20        94
#
#    Cloudiness  Wind Speed Current Description
# 0         100        5.20     overcast clouds
# 1          75        0.45       moderate rain
# 2         100        8.34     overcast clouds
# 3          80        3.17       broken clouds
# 4         100        1.59     overcast clouds
# 5         100        2.98     overcast clouds
# 6         100        7.82     overcast clouds
# 7          61        1.51       broken clouds
# 8          23        5.14          few clouds
# 9          90        0.00     overcast clouds

# %%
#saving df
weather_path = 'WeatherPy_Database.csv'

city_weather_df.to_csv(weather_path)
